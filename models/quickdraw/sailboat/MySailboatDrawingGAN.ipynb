# %% [markdown]
# # Privacy Preserving Generative Model
# This notebook aims to create a generative model which works in Python3

# %%
# !pip install imageio
# !pip install matplotlib
# !pip install tqdm
# Out:
# Collecting imageio
#   Downloading imageio-2.8.0-py3-none-any.whl (3.3 MB)
#      |################################| 3.3 MB 3.8 MB/s eta 0:00:01
# Collecting pillow
#   Downloading Pillow-7.0.0-cp36-cp36m-manylinux1_x86_64.whl (2.1 MB)
#      |################################| 2.1 MB 26.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages (from imageio) (1.18.1)
# Installing collected packages: pillow, imageio
# Successfully installed imageio-2.8.0 pillow-7.0.0
# Collecting matplotlib
#   Downloading matplotlib-3.2.0-cp36-cp36m-manylinux1_x86_64.whl (12.4 MB)
#      |################################| 12.4 MB 3.6 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.1 in /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: numpy>=1.11 in /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages (from matplotlib) (1.18.1)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1
#   Downloading pyparsing-2.4.6-py2.py3-none-any.whl (67 kB)
#      |################################| 67 kB 7.5 MB/s  eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (90 kB)
#      |################################| 90 kB 14.1 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages (from python-dateutil>=2.1->matplotlib) (1.14.0)
# Requirement already satisfied: setuptools in /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages (from kiwisolver>=1.0.1->matplotlib) (46.0.0)
# Installing collected packages: cycler, pyparsing, kiwisolver, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.1.0 matplotlib-3.2.0 pyparsing-2.4.6
# Collecting tqdm
#   Downloading tqdm-4.43.0-py2.py3-none-any.whl (59 kB)
#      |################################| 59 kB 2.7 MB/s eta 0:00:011
# Installing collected packages: tqdm
# Successfully installed tqdm-4.43.0

# %%
import time, os

# Numpy
import numpy as np

# Tensorflow and keras layers
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, Conv2DTranspose
from tensorflow.keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import activations
from tensorflow.keras import backend

# To generate GIFs


import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time


from tqdm import tqdm

from IPython import display
#tf.reset_default_graph()
# Out:
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def preprocess_real_samples(samples):
    samples = samples.astype('float32').reshape(-1, 28, 28, 1)
    samples = (samples - samples.min()) / (samples.max() - samples.min())
    return samples

def plot_4_by_4_images(x, save = False, savefile="img.png"):
    w=10
    h=10
    fig=plt.figure(figsize=(8, 8))
    columns = 4
    rows = 5
    for i in range(1, columns*rows +1):
        img = np.random.randint(x.shape[0])
        fig.add_subplot(rows, columns, i)
        plt.imshow(x[i - 1, :, :, 0], cmap='gray')
    if save:
        plt.savefig(savefile)
    plt.show()
    
dataset = np.load('sailboat.npy')
dataset = preprocess_real_samples(dataset) 
plot_4_by_4_images(dataset)

# %%
def generator_model():
    def square_activation(x):
        return x * x
    
    model = tf.keras.Sequential()
    model.add(layers.Dense(7*7*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())
    #model.add(Activation(square_activation))

    model.add(layers.Reshape((7, 7, 256)))
    assert model.output_shape == (None, 7, 7, 256) # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 7, 7, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())
    #model.add(Activation(square_activation))    

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 14, 14, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())
    #model.add(Activation(square_activation))
    
    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, 28, 28, 1)
    model.compile(loss='binary_crossentropy', optimizer='adam')
    
    return model
noise = np.random.normal(0, 1, [1, 100])
generator = generator_model()
generator.summary()
generated_image = generator.predict(noise)
print(generated_image.shape)
plt.imshow(generated_image[0, :, :, 0], cmap='gray')
# Out:
# WARNING:tensorflow:From /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 12544)             1254400
# _________________________________________________________________
# batch_normalization (BatchNo (None, 12544)             50176
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 12544)             0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 7, 7, 128)         819200
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 14, 14, 64)        204800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 1)         1600
# =================================================================
# Total params: 2,330,944
# Trainable params: 2,305,472
# Non-trainable params: 25,472
# _________________________________________________________________
# (1, 28, 28, 1)

# %%
def discriminator_model():
    def square_activation(x):
        return x * x
    
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same',
                                     input_shape=[28, 28, 1]))
    model.add(layers.LeakyReLU())
    #model.add(Activation(square_activation))
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
    #model.add(Activation(square_activation))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
discriminator = discriminator_model()
discriminator.summary()
pred= discriminator.predict(generated_image)
print(pred, pred > 0.5)
# Out:
# WARNING:tensorflow:From /root/he-transformer/build/ext_ngraph_tf/src/ext_ngraph_tf/build_cmake/venv-tf-py3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 14, 14, 64)        1664
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 128)         204928
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6273
# =================================================================
# Total params: 212,865
# Trainable params: 212,865
# Non-trainable params: 0
# _________________________________________________________________
# [[0.5005328]] [[ True]]

# %%
def gan_model(generator, discriminator):
    discriminator.trainable=False
    gan_input = Input(shape=(100,))
    x = generator(gan_input)
    gan_output = discriminator(x)
    gan= Model(inputs=gan_input, outputs=gan_output)
    gan.compile(loss='binary_crossentropy', optimizer='adam')
    return gan

gan = gan_model(generator, discriminator)
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         2330944
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 2,543,809
# Trainable params: 2,305,472
# Non-trainable params: 238,337
# _________________________________________________________________

# %%
def generate_noise_samples(n=1):
    noise = np.random.normal(0, 1, (n, 100))
    return noise
def generate_fake_samples(n=1):
    noise = generate_noise_samples(n)
    X = generator.predict(noise)
    return X

# %%
def generate_and_save_images(noise_test, epoch, batch):
    display.clear_output(wait=True)
    fake_images = generator.predict(noise_test)
    plot_4_by_4_images(fake_images, save=True, savefile='sailboat/image_at_epoch_{:04d}_{:04d}.png'.format(epoch, batch))

# %%
def train_step(real_images, batch_size=64):
        real_label = np.ones((batch_size, 1))
        generated_images = generate_fake_samples(batch_size)
        generated_labels = np.zeros((batch_size, 1))
        X_dis = np.concatenate([real_images, generated_images])
        y_dis = np.zeros(2*batch_size)
        y_dis[:batch_size]=0.9
        
        discriminator.trainable = True
        discriminator.train_on_batch(X_dis, y_dis)
        #discriminator.train_on_batch(x_fake, y_fake)
        
        discriminator.trainable = False
        x_gan = generate_noise_samples(batch_size)
        y_gan = np.ones((batch_size, 1)) # We assume that we wanted true as answer from the discriminator
        gan.train_on_batch(x_gan, y_gan)

# %%
def train(dataset, epochs=50, batch_size=64):
    m = dataset.shape[0]
    m_batch = m // batch_size
    noise_test = np.random.normal(0,1, [20, 100])
    toc = time.time()
    for epoch in range(epochs):
        tic = time.time()
        for batch_num in range(m_batch):
            if batch_num % 10 == 0:
                #print ('[{}%] Time for epoch {} is {} sec'.format((batch_num / m_batch) * 100,epoch + 1, time.time()-tic), end='\r')
                #generate_and_save_images(noise_test, epoch, batch_num)
                print("[%0.2f%%] Time for epoch %d is %f sec" % ( (batch_num / m_batch) * 100, epoch + 1, time.time()-tic), end='\r')    
            batch_slot = batch_size * batch_num
            batch = dataset[batch_slot: batch_slot + batch_size]
            train_step(batch, batch_size)
        #Extra
        
        if time.time() - toc  > 30:
            toc = time.time()
            generate_and_save_images(noise_test, epoch, batch_num)
        print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-tic))
    
    
train(dataset[:4000], 1000, 32)
# Out:
# Time for epoch 75 is 14.526558637619019 sec
# Time for epoch 76 is 11.550662994384766 sec
# Time for epoch 77 is 11.241541624069214 sec
# [16.00%] Time for epoch 78 is 1.832891 sec

# %%
generator.save('generator_sailboat_b.h5')
discriminator.save('discriminator_sailboat_b.h5')
gan.save('gan_sailboat_b.h5')

# %% [markdown]
# ### EXTRA CODE

# %%
# ### EXTRA CODE
# Out:
# ['img/image_at_epoch_0001_0155.png', 'img/image_at_epoch_0002_0124.png', 'img/image_at_epoch_0002_0155.png', 'img/image_at_epoch_0005_0061.png', 'img/image_at_epoch_0005_0124.png', 'img/image_at_epoch_0008_0124.png', 'img/image_at_epoch_0010_0030.png', 'img/image_at_epoch_0010_0061.png', 'img/image_at_epoch_0011_0030.png', 'img/image_at_epoch_0011_0124.png', 'img/image_at_epoch_0014_0124.png', 'img/image_at_epoch_0015_0061.png', 'img/image_at_epoch_0017_0124.png', 'img/image_at_epoch_0020_0030.png', 'img/image_at_epoch_0020_0061.png', 'img/image_at_epoch_0020_0124.png', 'img/image_at_epoch_0023_0124.png', 'img/image_at_epoch_0026_0061.png', 'img/image_at_epoch_0026_0124.png', 'img/image_at_epoch_0029_0124.png', 'img/image_at_epoch_0030_0030.png', 'img/image_at_epoch_0031_0061.png', 'img/image_at_epoch_0032_0124.png', 'img/image_at_epoch_0035_0124.png', 'img/image_at_epoch_0036_0061.png', 'img/image_at_epoch_0038_0124.png', 'img/image_at_epoch_0040_0030.png', 'img/image_at_epoch_0041_0061.png', 'img/image_at_epoch_0041_0124.png', 'img/image_at_epoch_0044_0124.png', 'img/image_at_epoch_0046_0061.png', 'img/image_at_epoch_0047_0124.png', 'img/image_at_epoch_0050_0030.png', 'img/image_at_epoch_0050_0124.png', 'img/image_at_epoch_0051_0061.png', 'img/image_at_epoch_0053_0124.png', 'img/image_at_epoch_0056_0061.png', 'img/image_at_epoch_0056_0124.png', 'img/image_at_epoch_0059_0124.png', 'img/image_at_epoch_0060_0030.png', 'img/image_at_epoch_0061_0061.png', 'img/image_at_epoch_0062_0124.png', 'img/image_at_epoch_0065_0124.png', 'img/image_at_epoch_0066_0061.png', 'img/image_at_epoch_0068_0124.png', 'img/image_at_epoch_0070_0030.png', 'img/image_at_epoch_0071_0061.png', 'img/image_at_epoch_0071_0124.png', 'img/image_at_epoch_0074_0124.png', 'img/image_at_epoch_0076_0061.png', 'img/image_at_epoch_0077_0124.png', 'img/image_at_epoch_0080_0030.png', 'img/image_at_epoch_0080_0124.png', 'img/image_at_epoch_0081_0061.png', 'img/image_at_epoch_0083_0124.png', 'img/image_at_epoch_0086_0061.png', 'img/image_at_epoch_0086_0124.png', 'img/image_at_epoch_0089_0124.png', 'img/image_at_epoch_0090_0030.png', 'img/image_at_epoch_0091_0061.png', 'img/image_at_epoch_0092_0124.png', 'img/image_at_epoch_0095_0124.png', 'img/image_at_epoch_0096_0061.png', 'img/image_at_epoch_0098_0124.png', 'img/image_at_epoch_0100_0030.png', 'img/image_at_epoch_0101_0061.png', 'img/image_at_epoch_0101_0124.png', 'img/image_at_epoch_0104_0124.png', 'img/image_at_epoch_0106_0061.png', 'img/image_at_epoch_0107_0124.png', 'img/image_at_epoch_0110_0030.png', 'img/image_at_epoch_0110_0124.png', 'img/image_at_epoch_0111_0061.png', 'img/image_at_epoch_0113_0124.png', 'img/image_at_epoch_0116_0061.png', 'img/image_at_epoch_0116_0124.png', 'img/image_at_epoch_0119_0124.png', 'img/image_at_epoch_0120_0030.png', 'img/image_at_epoch_0121_0061.png', 'img/image_at_epoch_0122_0124.png', 'img/image_at_epoch_0125_0124.png', 'img/image_at_epoch_0126_0061.png', 'img/image_at_epoch_0128_0124.png', 'img/image_at_epoch_0130_0030.png', 'img/image_at_epoch_0131_0061.png', 'img/image_at_epoch_0131_0124.png', 'img/image_at_epoch_0134_0124.png', 'img/image_at_epoch_0136_0061.png', 'img/image_at_epoch_0137_0124.png', 'img/image_at_epoch_0140_0030.png', 'img/image_at_epoch_0140_0124.png', 'img/image_at_epoch_0141_0061.png', 'img/image_at_epoch_0143_0124.png', 'img/image_at_epoch_0146_0061.png', 'img/image_at_epoch_0146_0124.png', 'img/image_at_epoch_0149_0124.png', 'img/image_at_epoch_0150_0030.png', 'img/image_at_epoch_0151_0061.png', 'img/image_at_epoch_0152_0124.png', 'img/image_at_epoch_0155_0124.png', 'img/image_at_epoch_0156_0061.png', 'img/image_at_epoch_0158_0124.png', 'img/image_at_epoch_0160_0030.png', 'img/image_at_epoch_0161_0061.png', 'img/image_at_epoch_0161_0124.png', 'img/image_at_epoch_0164_0124.png', 'img/image_at_epoch_0166_0061.png', 'img/image_at_epoch_0167_0124.png', 'img/image_at_epoch_0170_0030.png', 'img/image_at_epoch_0170_0124.png', 'img/image_at_epoch_0171_0061.png', 'im ...
# img/image_at_epoch_0001_0155.png
# img/image_at_epoch_0002_0124.png
# img/image_at_epoch_0002_0155.png
# img/image_at_epoch_0005_0061.png
# img/image_at_epoch_0005_0124.png
# img/image_at_epoch_0008_0124.png
# img/image_at_epoch_0010_0030.png
# img/image_at_epoch_0010_0061.png
# img/image_at_epoch_0011_0030.png
# img/image_at_epoch_0011_0124.png
# img/image_at_epoch_0014_0124.png
# img/image_at_epoch_0015_0061.png
# img/image_at_epoch_0017_0124.png
# img/image_at_epoch_0020_0030.png
# img/image_at_epoch_0020_0061.png
# img/image_at_epoch_0020_0124.png
# img/image_at_epoch_0023_0124.png
# img/image_at_epoch_0026_0061.png
# img/image_at_epoch_0026_0124.png
# img/image_at_epoch_0029_0124.png
# img/image_at_epoch_0030_0030.png
# img/image_at_epoch_0031_0061.png
# img/image_at_epoch_0032_0124.png
# img/image_at_epoch_0035_0124.png
# img/image_at_epoch_0036_0061.png
# img/image_at_epoch_0038_0124.png
# img/image_at_epoch_0040_0030.png
# img/image_at_epoch_0041_0061.png
# img/image_at_epoch_0041_0124.png
# img/image_at_epoch_0044_0124.png
# img/image_at_epoch_0046_0061.png
# img/image_at_epoch_0047_0124.png
# img/image_at_epoch_0050_0030.png
# img/image_at_epoch_0050_0124.png
# img/image_at_epoch_0051_0061.png
# img/image_at_epoch_0053_0124.png
# img/image_at_epoch_0056_0061.png
# img/image_at_epoch_0056_0124.png
# img/image_at_epoch_0059_0124.png
# img/image_at_epoch_0060_0030.png
# img/image_at_epoch_0061_0061.png
# img/image_at_epoch_0062_0124.png
# img/image_at_epoch_0065_0124.png
# img/image_at_epoch_0066_0061.png
# img/image_at_epoch_0068_0124.png
# img/image_at_epoch_0070_0030.png
# img/image_at_epoch_0071_0061.png
# img/image_at_epoch_0071_0124.png
# img/image_at_epoch_0074_0124.png
# img/image_at_epoch_0076_0061.png
# img/image_at_epoch_0077_0124.png
# img/image_at_epoch_0080_0030.png
# img/image_at_epoch_0080_0124.png
# img/image_at_epoch_0081_0061.png
# img/image_at_epoch_0083_0124.png
# img/image_at_epoch_0086_0061.png
# img/image_at_epoch_0086_0124.png
# img/image_at_epoch_0089_0124.png
# img/image_at_epoch_0090_0030.png
# img/image_at_epoch_0091_0061.png
# img/image_at_epoch_0092_0124.png
# img/image_at_epoch_0095_0124.png
# img/image_at_epoch_0096_0061.png
# img/image_at_epoch_0098_0124.png
# img/image_at_epoch_0100_0030.png
# img/image_at_epoch_0101_0061.png
# img/image_at_epoch_0101_0124.png
# img/image_at_epoch_0104_0124.png
# img/image_at_epoch_0106_0061.png
# img/image_at_epoch_0107_0124.png
# img/image_at_epoch_0110_0030.png
# img/image_at_epoch_0110_0124.png
# img/image_at_epoch_0111_0061.png
# img/image_at_epoch_0113_0124.png
# img/image_at_epoch_0116_0061.png
# img/image_at_epoch_0116_0124.png
# img/image_at_epoch_0119_0124.png
# img/image_at_epoch_0120_0030.png
# img/image_at_epoch_0121_0061.png
# img/image_at_epoch_0122_0124.png
# img/image_at_epoch_0125_0124.png
# img/image_at_epoch_0126_0061.png
# img/image_at_epoch_0128_0124.png
# img/image_at_epoch_0130_0030.png
# img/image_at_epoch_0131_0061.png
# img/image_at_epoch_0131_0124.png
# img/image_at_epoch_0134_0124.png
# img/image_at_epoch_0136_0061.png
# img/image_at_epoch_0137_0124.png
# img/image_at_epoch_0140_0030.png
# img/image_at_epoch_0140_0124.png
# img/image_at_epoch_0141_0061.png
# img/image_at_epoch_0143_0124.png
# img/image_at_epoch_0146_0061.png
# img/image_at_epoch_0146_0124.png
# img/image_at_epoch_0149_0124.png
# img/image_at_epoch_0150_0030.png
# img/image_at_epoch_0151_0061.png
# img/image_at_epoch_0152_0124.png
# img/image_at_epoch_0155_0124.png
# img/image_at_epoch_0156_0061.png
# img/image_at_epoch_0158_0124.png
# img/image_at_epoch_0160_0030.png
# img/image_at_epoch_0161_0061.png
# img/image_at_epoch_0161_0124.png
# img/image_at_epoch_0164_0124.png
# img/image_at_epoch_0166_0061.png
# img/image_at_epoch_0167_0124.png
# img/image_at_epoch_0170_0030.png
# img/image_at_epoch_0170_0124.png
# img/image_at_epoch_0171_0061.png
# img/image_at_epoch_0173_0124.png
# img/image_at_epoch_0176_0061.png
# img/image_at_epoch_0176_0124.png
# img/image_at_epoch_0179_0124.png
# img/image_at_epoch_0180_0030.png
# img/image_at_epoch_0181_0061.png
# img/image_at_epoch_0182_0124.png
# img/image_at_epoch_0185_0124.png
# img/image_at_epoch_0186_0061.png
# img/image_at_epoch_0188_0124.png
# img/image_at_epoch_0190_0030.png
# img/image_at_epoch_0191_0061.png
# img/image_at_epoch_0191_0124.png
# img/image_at_epoch_0194_0124.png
# img/image_at_epoch_0196_0061.png
# img/image_at_epoch_0197_0124.png
# img/image_at_epoch_0200_0030.png
# img/image_at_epoch_0200_0124.png
# img/image_at_epoch_0201_0061.png
# img/image_at_epoch_0203_0124.png
# img/image_at_epoch_0206_0061.png
# img/image_at_epoch_0206_0124.png
# img/image_at_epoch_0209_0124.png
# img/image_at_epoch_0210_0030.png
# img/image_at_epoch_0211_0061.png
# img/image_at_epoch_0212_0124.png
# img/image_at_epoch_0215_0124.png
# img/image_at_epoch_0216_0061.png
# img/image_at_epoch_0218_0124.png
# img/image_at_epoch_0220_0030.png
# img/image_at_epoch_0221_0061.png
# img/image_at_epoch_0221_0124.png
# img/image_at_epoch_0224_0124.png
# img/image_at_epoch_0226_0061.png
# img/image_at_epoch_0227_0124.png
# img/image_at_epoch_0230_0030.png
# img/image_at_epoch_0230_0124.png
# img/image_at_epoch_0231_0061.png
# img/image_at_epoch_0233_0124.png
# img/image_at_epoch_0236_0061.png
# img/image_at_epoch_0236_0124.png
# img/image_at_epoch_0239_0124.png
# img/image_at_epoch_0240_0030.png
# img/image_at_epoch_0241_0061.png
# img/image_at_epoch_0242_0124.png
# img/image_at_epoch_0245_0124.png
# img/image_at_epoch_0246_0061.png
# img/image_at_epoch_0248_0124.png
# img/image_at_epoch_0250_0030.png
# img/image_at_epoch_0251_0061.png
# img/image_at_epoch_0251_0124.png
# img/image_at_epoch_0254_0124.png
# img/image_at_epoch_0256_0061.png
# img/image_at_epoch_0257_0124.png
# img/image_at_epoch_0260_0030.png
# img/image_at_epoch_0260_0124.png
# img/image_at_epoch_0261_0061.png
# img/image_at_epoch_0263_0124.png
# img/image_at_epoch_0266_0061.png
# img/image_at_epoch_0266_0124.png
# img/image_at_epoch_0269_0124.png
# img/image_at_epoch_0270_0030.png
# img/image_at_epoch_0271_0061.png
# img/image_at_epoch_0272_0124.png
# img/image_at_epoch_0275_0124.png
# img/image_at_epoch_0276_0061.png
# img/image_at_epoch_0278_0124.png
# img/image_at_epoch_0280_0030.png
# img/image_at_epoch_0281_0061.png
# img/image_at_epoch_0281_0124.png
# img/image_at_epoch_0284_0124.png
# img/image_at_epoch_0286_0061.png
# img/image_at_epoch_0287_0124.png
# img/image_at_epoch_0290_0030.png
# img/image_at_epoch_0290_0124.png
# img/image_at_epoch_0291_0061.png
# img/image_at_epoch_0293_0124.png
# img/image_at_epoch_0296_0061.png
# img/image_at_epoch_0296_0124.png
# img/image_at_epoch_0299_0124.png
# img/image_at_epoch_0300_0030.png
# img/image_at_epoch_0301_0061.png
# img/image_at_epoch_0302_0124.png
# img/image_at_epoch_0305_0124.png
# img/image_at_epoch_0306_0061.png
# img/image_at_epoch_0308_0124.png
# img/image_at_epoch_0310_0030.png
# img/image_at_epoch_0311_0061.png
# img/image_at_epoch_0311_0124.png
# img/image_at_epoch_0314_0124.png
# img/image_at_epoch_0316_0061.png
# img/image_at_epoch_0317_0124.png
# img/image_at_epoch_0320_0030.png
# img/image_at_epoch_0320_0124.png
# img/image_at_epoch_0321_0061.png
# img/image_at_epoch_0323_0124.png
# img/image_at_epoch_0326_0061.png
# img/image_at_epoch_0326_0124.png
# img/image_at_epoch_0329_0124.png
# img/image_at_epoch_0330_0030.png
# img/image_at_epoch_0331_0061.png
# img/image_at_epoch_0332_0124.png
# img/image_at_epoch_0335_0124.png
# img/image_at_epoch_0336_0061.png
# img/image_at_epoch_0338_0124.png
# img/image_at_epoch_0340_0030.png
# img/image_at_epoch_0341_0061.png
# img/image_at_epoch_0341_0124.png
# img/image_at_epoch_0344_0124.png
# img/image_at_epoch_0346_0061.png
# img/image_at_epoch_0347_0124.png
# img/image_at_epoch_0350_0030.png
# img/image_at_epoch_0350_0124.png
# img/image_at_epoch_0351_0061.png
# img/image_at_epoch_0353_0124.png
# img/image_at_epoch_0356_0061.png
# img/image_at_epoch_0356_0124.png
# img/image_at_epoch_0359_0124.png
# img/image_at_epoch_0360_0030.png
# img/image_at_epoch_0361_0061.png
# img/image_at_epoch_0362_0124.png
# img/image_at_epoch_0365_0124.png
# img/image_at_epoch_0366_0061.png
# img/image_at_epoch_0368_0124.png
# img/image_at_epoch_0370_0030.png
# img/image_at_epoch_0371_0061.png
# img/image_at_epoch_0371_0124.png
# img/image_at_epoch_0374_0124.png
# img/image_at_epoch_0376_0061.png
# img/image_at_epoch_0377_0124.png
# img/image_at_epoch_0380_0030.png
# img/image_at_epoch_0380_0124.png
# img/image_at_epoch_0381_0061.png
# img/image_at_epoch_0383_0124.png
# img/image_at_epoch_0386_0061.png
# img/image_at_epoch_0386_0124.png
# img/image_at_epoch_0389_0124.png
# img/image_at_epoch_0390_0030.png
# img/image_at_epoch_0391_0061.png
# img/image_at_epoch_0392_0124.png
# img/image_at_epoch_0395_0124.png
# img/image_at_epoch_0396_0061.png
# img/image_at_epoch_0398_0124.png
# img/image_at_epoch_0400_0030.png
# img/image_at_epoch_0401_0061.png
# img/image_at_epoch_0401_0124.png
# img/image_at_epoch_0404_0124.png
# img/image_at_epoch_0406_0061.png
# img/image_at_epoch_0407_0124.png
# img/image_at_epoch_0410_0030.png
# img/image_at_epoch_0410_0124.png
# img/image_at_epoch_0411_0061.png
# img/image_at_epoch_0413_0124.png
# img/image_at_epoch_0416_0061.png
# img/image_at_epoch_0416_0124.png
# img/image_at_epoch_0419_0124.png
# img/image_at_epoch_0420_0030.png
# img/image_at_epoch_0421_0061.png
# img/image_at_epoch_0422_0124.png
# img/image_at_epoch_0425_0124.png
# img/image_at_epoch_0426_0061.png
# img/image_at_epoch_0428_0124.png
# img/image_at_epoch_0430_0030.png
# img/image_at_epoch_0431_0061.png
# img/image_at_epoch_0431_0124.png
# img/image_at_epoch_0434_0124.png
# img/image_at_epoch_0436_0061.png
# img/image_at_epoch_0437_0124.png
# img/image_at_epoch_0440_0030.png
# img/image_at_epoch_0440_0124.png
# img/image_at_epoch_0441_0061.png
# img/image_at_epoch_0443_0124.png
# img/image_at_epoch_0446_0061.png
# img/image_at_epoch_0446_0124.png
# img/image_at_epoch_0449_0124.png
# img/image_at_epoch_0450_0030.png
# img/image_at_epoch_0451_0061.png
# img/image_at_epoch_0452_0124.png
# img/image_at_epoch_0455_0124.png
# img/image_at_epoch_0456_0061.png
# img/image_at_epoch_0458_0124.png
# img/image_at_epoch_0460_0030.png
# img/image_at_epoch_0461_0061.png
# img/image_at_epoch_0461_0124.png
# img/image_at_epoch_0464_0124.png
# img/image_at_epoch_0466_0061.png
# img/image_at_epoch_0467_0124.png
# img/image_at_epoch_0470_0030.png
# img/image_at_epoch_0470_0124.png
# img/image_at_epoch_0471_0061.png
# img/image_at_epoch_0473_0124.png
# img/image_at_epoch_0476_0061.png
# img/image_at_epoch_0476_0124.png
# img/image_at_epoch_0479_0124.png
# img/image_at_epoch_0480_0030.png
# img/image_at_epoch_0481_0061.png
# img/image_at_epoch_0482_0124.png
# img/image_at_epoch_0485_0124.png
# img/image_at_epoch_0486_0061.png
# img/image_at_epoch_0488_0124.png
# img/image_at_epoch_0490_0030.png
# img/image_at_epoch_0491_0061.png
# img/image_at_epoch_0491_0124.png
# img/image_at_epoch_0494_0124.png
# img/image_at_epoch_0496_0061.png
# img/image_at_epoch_0497_0124.png
# img/image_at_epoch_0500_0124.png
# img/image_at_epoch_0503_0124.png
# img/image_at_epoch_0506_0124.png
# img/image_at_epoch_0509_0124.png
# img/image_at_epoch_0512_0124.png
# img/image_at_epoch_0515_0124.png
# img/image_at_epoch_0518_0124.png
# img/image_at_epoch_0521_0124.png
# img/image_at_epoch_0524_0124.png
# img/image_at_epoch_0527_0124.png
# img/image_at_epoch_0530_0124.png
# img/image_at_epoch_0533_0124.png
# img/image_at_epoch_0536_0124.png
# img/image_at_epoch_0539_0124.png
# img/image_at_epoch_0542_0124.png
# img/image_at_epoch_0545_0124.png
# img/image_at_epoch_0548_0124.png
# img/image_at_epoch_0551_0124.png
# img/image_at_epoch_0554_0124.png
# img/image_at_epoch_0557_0124.png
# img/image_at_epoch_0560_0124.png
# img/image_at_epoch_0563_0124.png
# img/image_at_epoch_0566_0124.png
# img/image_at_epoch_0569_0124.png
# img/image_at_epoch_0572_0124.png
# img/image_at_epoch_0575_0124.png
# img/image_at_epoch_0578_0124.png
# img/image_at_epoch_0581_0124.png
# img/image_at_epoch_0584_0124.png
# img/image_at_epoch_0587_0124.png
# img/image_at_epoch_0590_0124.png
# img/image_at_epoch_0593_0124.png
# img/image_at_epoch_0596_0124.png
# img/image_at_epoch_0599_0124.png
# img/image_at_epoch_0602_0124.png
# img/image_at_epoch_0605_0124.png
# img/image_at_epoch_0608_0124.png
# img/image_at_epoch_0611_0124.png
# img/image_at_epoch_0614_0124.png
# img/image_at_epoch_0617_0124.png
# img/image_at_epoch_0620_0124.png
# img/image_at_epoch_0623_0124.png
# img/image_at_epoch_0626_0124.png
# img/image_at_epoch_0629_0124.png
# img/image_at_epoch_0632_0124.png
# img/image_at_epoch_0635_0124.png
# img/image_at_epoch_0638_0124.png
# img/image_at_epoch_0641_0124.png
# img/image_at_epoch_0644_0124.png
# img/image_at_epoch_0647_0124.png
# img/image_at_epoch_0650_0124.png
# img/image_at_epoch_0653_0124.png
# img/image_at_epoch_0656_0124.png
# img/image_at_epoch_0659_0124.png
# img/image_at_epoch_0662_0124.png
# img/image_at_epoch_0665_0124.png
# img/image_at_epoch_0668_0124.png
# img/image_at_epoch_0671_0124.png
# img/image_at_epoch_0674_0124.png
# img/image_at_epoch_0677_0124.png
# img/image_at_epoch_0680_0124.png
# img/image_at_epoch_0683_0124.png
# img/image_at_epoch_0686_0124.png
# img/image_at_epoch_0689_0124.png
# img/image_at_epoch_0692_0124.png
# img/image_at_epoch_0695_0124.png
# img/image_at_epoch_0698_0124.png
# img/image_at_epoch_0701_0124.png
# img/image_at_epoch_0704_0124.png
# img/image_at_epoch_0707_0124.png
# img/image_at_epoch_0710_0124.png
# img/image_at_epoch_0713_0124.png
# img/image_at_epoch_0716_0124.png
# img/image_at_epoch_0719_0124.png
# img/image_at_epoch_0722_0124.png
# img/image_at_epoch_0725_0124.png
# img/image_at_epoch_0728_0124.png
# img/image_at_epoch_0731_0124.png
# img/image_at_epoch_0734_0124.png
# img/image_at_epoch_0737_0124.png
# img/image_at_epoch_0740_0124.png
# img/image_at_epoch_0743_0124.png
# img/image_at_epoch_0746_0124.png
# img/image_at_epoch_0749_0124.png
# img/image_at_epoch_0752_0124.png
# img/image_at_epoch_0755_0124.png
# img/image_at_epoch_0758_0124.png
# img/image_at_epoch_0761_0124.png
# img/image_at_epoch_0764_0124.png
# img/image_at_epoch_0767_0124.png
# img/image_at_epoch_0770_0124.png
# img/image_at_epoch_0773_0124.png
# img/image_at_epoch_0776_0124.png
# img/image_at_epoch_0779_0124.png
# img/image_at_epoch_0782_0124.png
# img/image_at_epoch_0785_0124.png
# img/image_at_epoch_0788_0124.png
# img/image_at_epoch_0791_0124.png
# img/image_at_epoch_0794_0124.png
# img/image_at_epoch_0797_0124.png
# img/image_at_epoch_0800_0124.png
# img/image_at_epoch_0803_0124.png
# img/image_at_epoch_0806_0124.png
# img/image_at_epoch_0809_0124.png
# img/image_at_epoch_0812_0124.png
# img/image_at_epoch_0815_0124.png
# img/image_at_epoch_0818_0124.png
# img/image_at_epoch_0821_0124.png
# img/image_at_epoch_0824_0124.png
# img/image_at_epoch_0827_0124.png
# img/image_at_epoch_0830_0124.png
# img/image_at_epoch_0833_0124.png
# img/image_at_epoch_0836_0124.png
# img/image_at_epoch_0839_0124.png
# img/image_at_epoch_0842_0124.png
# img/image_at_epoch_0845_0124.png
# img/image_at_epoch_0848_0124.png
# img/image_at_epoch_0851_0124.png
# img/image_at_epoch_0854_0124.png
# img/image_at_epoch_0857_0124.png
# img/image_at_epoch_0860_0124.png
# img/image_at_epoch_0863_0124.png
# img/image_at_epoch_0866_0124.png
# img/image_at_epoch_0869_0124.png
# img/image_at_epoch_0872_0124.png
# img/image_at_epoch_0875_0124.png
# img/image_at_epoch_0878_0124.png
# img/image_at_epoch_0881_0124.png
# img/image_at_epoch_0884_0124.png
# img/image_at_epoch_0887_0124.png
# img/image_at_epoch_0890_0124.png
# img/image_at_epoch_0893_0124.png
# img/image_at_epoch_0896_0124.png
# img/image_at_epoch_0899_0124.png
# img/image_at_epoch_0902_0124.png
# img/image_at_epoch_0905_0124.png
# img/image_at_epoch_0908_0124.png
# img/image_at_epoch_0911_0124.png
# img/image_at_epoch_0914_0124.png
# img/image_at_epoch_0917_0124.png
# img/image_at_epoch_0920_0124.png
# img/image_at_epoch_0923_0124.png
# img/image_at_epoch_0926_0124.png
# img/image_at_epoch_0929_0124.png
# img/image_at_epoch_0932_0124.png
# img/image_at_epoch_0935_0124.png
# img/image_at_epoch_0938_0124.png
# img/image_at_epoch_0941_0124.png
# img/image_at_epoch_0944_0124.png
# img/image_at_epoch_0947_0124.png
# img/image_at_epoch_0950_0124.png
# img/image_at_epoch_0953_0124.png
# img/image_at_epoch_0956_0124.png
# img/image_at_epoch_0959_0124.png
# img/image_at_epoch_0962_0124.png
# img/image_at_epoch_0965_0124.png
# img/image_at_epoch_0968_0124.png
# img/image_at_epoch_0971_0124.png
# img/image_at_epoch_0974_0124.png
# img/image_at_epoch_0977_0124.png
# img/image_at_epoch_0980_0124.png
# img/image_at_epoch_0983_0124.png
# img/image_at_epoch_0986_0124.png
# img/image_at_epoch_0989_0124.png
# img/image_at_epoch_0992_0124.png
# img/image_at_epoch_0995_0124.png
# img/image_at_epoch_0998_0124.png

# %%
anim_file = 'dcgan.gif'
with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('sailboat/i_*.png')
  filenames = sorted(filenames)
  last = -1
  for i,filename in enumerate(filenames):
    frame = 2*(i**0.5)
    if round(frame) > round(last):last = frame
    else:
      continue
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2a7df742961b> in <module>
#      12     image = imageio.imread(filename)
#      13     writer.append_data(image)
# ---> 14   image = imageio.imread(filename)
#      15   writer.append_data(image)
#
# NameError: name 'filename' is not defined
